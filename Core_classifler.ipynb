# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
import re 
from sklearn.cluster import KMeans

# %%
iris = load_iris()

# %%
df = pd.DataFrame({
    'sepal length':iris.data[:,0],
    'sepal width':iris.data[:,1],
    'petal length':iris.data[:,2],
    'petal width':iris.data[:,3],
    'species':iris.target
})
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x=df['sepal length'],y=df['petal length'],data=df,hue=df['species'])
# Out:
# <AxesSubplot:xlabel='sepal length', ylabel='petal length'>

# %%
km = KMeans(n_clusters=3)
km.fit(df)
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
x = df["sepal length"]
y = df["petal length"]

sns.scatterplot(x=df['sepal length'],y=df['petal length'],data=df,hue=df['species'])
plt.show()

#plt.scatter(x, y, c=km.labels_)
#plt.subplot(2,1,2)
#plt.show()

# %%
plt.scatter(x, y, c=km.labels_)
plt.xlabel("Sepal length")
plt.ylabel("Petal length")
plt.show()
